# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
label = pd.read_csv('../data/test_dataset_label.csv')

# %%
notes = pd.read_csv('../data/final_patient_data_table_test_full.csv')

# %%
to_filter_notes = notes.copy()

# %%
to_filter_notes = to_filter_notes[to_filter_notes['empi'].isin(label['empi'])]
merged_df = pd.merge(to_filter_notes, label, on='empi')
print(len(merged_df['empi'].unique()))

# %%
merged_df.to_csv('../data/test_merged_data.csv', index=False)
